# %%
import os
from dotenv import load_dotenv

# %%
load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# %%
cd ..
# Out:
# c:\Users\admin\Downloads\Knowledge\langchain-interview

# %%
# %pwd
# Out:
# 'c:\\Users\\admin\\Downloads\\Knowledge\\langchain-interview'

# %%
from langchain_community.document_loaders import PyPDFLoader

# %%
file_path = "data/SWE.pdf"
loader = PyPDFLoader(file_path)
data = loader.load()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 2
#       1 file_path = "data/SWE.pdf"
# ----> 2 loader = PyPDFLoader(file_path)
#       3 data = loader.load()
#
# File c:\Users\admin\anaconda3\envs\interview\lib\site-packages\langchain_community\document_loaders\pdf.py:281, in PyPDFLoader.__init__(self, file_path, password, headers, extract_images, mode, images_parser, images_inner_format, pages_delimiter, extraction_mode, extraction_kwargs)
#     238 def __init__(
#     239     self,
#     240     file_path: Union[str, PurePath],
#    (...)
#     250     extraction_kwargs: Optional[dict] = None,
#     251 ) -> None:
#     252     """Initialize with a file path.
#     253
#     254     Args:
#    (...)
#     279         `aload` methods to retrieve parsed documents with content and metadata.
#     280     """
# --> 281     super().__init__(file_path, headers=headers)
#     282     self.parser = PyPDFParser(
#     283         password=password,
#     284         mode=mode,
#    (...)
#     290         extraction_kwargs=extraction_kwargs,
#     291     )
#
# File c:\Users\admin\anaconda3\envs\interview\lib\site-packages\langchain_community\document_loaders\pdf.py:140, in BasePDFLoader.__init__(self, file_path, headers)
#     138         self.file_path = str(temp_pdf)
#     139 elif not os.path.isfile(self.file_path):
# --> 140     raise ValueError("File path %s is not a valid file or url" % self.file_path)
#
# ValueError: File path data/SWE.pdf is not a valid file or url

# %%
data
# Out:
# [Document(metadata={'producer': 'Microsoft® Word 2016', 'creator': 'Microsoft® Word 2016', 'creationdate': '2025-12-28T18:01:13+07:00', 'author': 'Phan Si Nguyen', 'moddate': '2025-12-28T18:01:13+07:00', 'source': 'data/SWE.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content="Senior Software Engineer, Engineering Productivity \nGoogleplaceSan Jose, CA, USA \nMinimum qualifications: \n• Bachelor’s degree or equivalent practical experience. \n• 5 years of experience with software development in one or more programming \nlanguages. \n• 3 years of experience working with embedded operating systems. \n• 3 years of experience testing, maintaining, or launching software products. \n• 1 year of experience with software design and architecture. \n \n \n \nPreferred qualifications: \n• Master's degree or PhD in Computer Science or related technical field. \n• 5 years of experience with data structures/algorithms. \n• 1 year of experience in a technical leadership role. \n• Experience developing accessible technologies. \nAbout the job \nGoogle's software engineers develop the next-generation technologies that change how \nbillions of users connect, explore, and interact with information and one another. Our \nproducts need to handle information at massive scale, and extend well beyond web \nsearch. We're looking for engineers who bring fresh ideas from all areas, including \ninformation retrieval, distributed computing, large-scale system design, networking and \ndata storage, security, artificial intelligence, natural language processing, UI design and \nmobile; the list goes on and is growing every day. As a software engineer, you will work on a \nspecific project critical to Google’s needs with opportunities to switch teams and projects \nas you and our fast-paced business grow and evolve. We need our engineers to be versatile, \ndisplay leadership qualities and be enthusiastic to take on new problems across the full-\nstack as we continue to push technology forward. Android is Google’s mobile operating \nsystem powering more than 3 billion devices worldwide. Android is about bringing \ncomputing to everyone in the world. We believe computing is a super power for good,"),
#  Document(metadata={'producer': 'Microsoft® Word 2016', 'creator': 'Microsoft® Word 2016', 'creationdate': '2025-12-28T18:01:13+07:00', 'author': 'Phan Si Nguyen', 'moddate': '2025-12-28T18:01:13+07:00', 'source': 'data/SWE.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2'}, page_content='enabling access to information, economic opportunity, productivity, connectivity between \nfriends and family and more. We think everyone in the world should have access to the best \ncomputing has to offer. We provide the platform for original equipment manufacturers \n(OEMs) and developers to build compelling computing devices (smartphones, tablets, TVs, \nwearables, etc) that run the best apps/services for everyone in the world. \n \nThe US base salary range for this full-time position is $166,000-$244,000 + bonus + equity + \nbenefits. Our salary ranges are determined by role, level, and location. Within the range, \nindividual pay is determined by work location and additional factors, including job-related \nskills, experience, and relevant education or training. Your recruiter can share more about \nthe specific salary range for your preferred location during the hiring process. \n \nPlease note that the compensation details listed in US role postings reflect the base salary \nonly, and do not include bonus, equity, or benefits. Learn more about benefits at Google. \nResponsibilities \n• Write and test product or system development code. \n• Participate in, or lead design reviews with peers and stakeholders to decide \namongst available technologies. \n• Review code developed by other developers and provide feedback to ensure best \npractices (e.g., style guidelines, checking code in, accuracy, testability, and \nefficiency). \n• Contribute to existing documentation or educational content and adapt content \nbased on product/program updates and user feedback. \n• Triage product or system issues and debug/track/resolve by analyzing the sources of \nissues and the impact on hardware, network, or service operations and quality.')]

# %%
len(data) # pages
# Out:
# 2

# %%
question_gen = ""
for page in data:
    question_gen += page.page_content

# %%
question_gen
# Out:
# "Senior Software Engineer, Engineering Productivity \nGoogleplaceSan Jose, CA, USA \nMinimum qualifications: \n• Bachelor’s degree or equivalent practical experience. \n• 5 years of experience with software development in one or more programming \nlanguages. \n• 3 years of experience working with embedded operating systems. \n• 3 years of experience testing, maintaining, or launching software products. \n• 1 year of experience with software design and architecture. \n \n \n \nPreferred qualifications: \n• Master's degree or PhD in Computer Science or related technical field. \n• 5 years of experience with data structures/algorithms. \n• 1 year of experience in a technical leadership role. \n• Experience developing accessible technologies. \nAbout the job \nGoogle's software engineers develop the next-generation technologies that change how \nbillions of users connect, explore, and interact with information and one another. Our \nproducts need to handle information at massive scale, and extend well beyond web \nsearch. We're looking for engineers who bring fresh ideas from all areas, including \ninformation retrieval, distributed computing, large-scale system design, networking and \ndata storage, security, artificial intelligence, natural language processing, UI design and \nmobile; the list goes on and is growing every day. As a software engineer, you will work on a \nspecific project critical to Google’s needs with opportunities to switch teams and projects \nas you and our fast-paced business grow and evolve. We need our engineers to be versatile, \ndisplay leadership qualities and be enthusiastic to take on new problems across the full-\nstack as we continue to push technology forward. Android is Google’s mobile operating \nsystem powering more than 3 billion devices worldwide. Android is about bringing \ncomputing to everyone in the world. We believe computing is a super power for good,enabling access to information, economic opportunity, productivity, connectivity between \nfriends and family and more. We think everyone in the world should have access to the best \ncomputing has to offer. We provide the platform for original equipment manufacturers \n(OEMs) and developers to build compelling computing devices (smartphones, tablets, TVs, \nwearables, etc) that run the best apps/services for everyone in the world. \n \nThe US base salary range for this full-time position is $166,000-$244,000 + bonus + equity + \nbenefits. Our salary ranges are determined by role, level, and location. Within the range, \nindividual pay is determined by work location and additional factors, including job-related \nskills, experience, and relevant education or training. Your recruiter can share more about \nthe specific salary range for your preferred location during the hiring process. \n \nPlease note that the compensation details listed in US role postings reflect the base salary \nonly, and do not include bonus, equity, or benefits. Learn more about benefits at Google. \nResponsibilities \n• Write and test product or system development code. \n• Participate in, or lead design reviews with peers and stakeholders to decide \namongst available technologies. \n• Review code developed by other developers and provide feedback to ensure best \npractices (e.g., style guidelines, checking code in, accuracy, testability, and \nefficiency). \n• Contribute to existing documentation or educational content and adapt content \nbased on product/program updates and user feedback. \n• Triage product or system issues and debug/track/resolve by analyzing the sources of \nissues and the impact on hardware, network, or service operations and quality."

# %%
from langchain_text_splitters import TokenTextSplitter

# %%
splitter_ques_gen = TokenTextSplitter(
    model_name= "gpt-4.1-mini",
    chunk_size= 10000,
    chunk_overlap = 200
)

# %%
chunk_ques_gen = splitter_ques_gen.split_text(question_gen)

# %%
chunk_ques_gen
# Out:
# ["Senior Software Engineer, Engineering Productivity \nGoogleplaceSan Jose, CA, USA \nMinimum qualifications: \n• Bachelor’s degree or equivalent practical experience. \n• 5 years of experience with software development in one or more programming \nlanguages. \n• 3 years of experience working with embedded operating systems. \n• 3 years of experience testing, maintaining, or launching software products. \n• 1 year of experience with software design and architecture. \n \n \n \nPreferred qualifications: \n• Master's degree or PhD in Computer Science or related technical field. \n• 5 years of experience with data structures/algorithms. \n• 1 year of experience in a technical leadership role. \n• Experience developing accessible technologies. \nAbout the job \nGoogle's software engineers develop the next-generation technologies that change how \nbillions of users connect, explore, and interact with information and one another. Our \nproducts need to handle information at massive scale, and extend well beyond web \nsearch. We're looking for engineers who bring fresh ideas from all areas, including \ninformation retrieval, distributed computing, large-scale system design, networking and \ndata storage, security, artificial intelligence, natural language processing, UI design and \nmobile; the list goes on and is growing every day. As a software engineer, you will work on a \nspecific project critical to Google’s needs with opportunities to switch teams and projects \nas you and our fast-paced business grow and evolve. We need our engineers to be versatile, \ndisplay leadership qualities and be enthusiastic to take on new problems across the full-\nstack as we continue to push technology forward. Android is Google’s mobile operating \nsystem powering more than 3 billion devices worldwide. Android is about bringing \ncomputing to everyone in the world. We believe computing is a super power for good,enabling access to information, economic opportunity, productivity, connectivity between \nfriends and family and more. We think everyone in the world should have access to the best \ncomputing has to offer. We provide the platform for original equipment manufacturers \n(OEMs) and developers to build compelling computing devices (smartphones, tablets, TVs, \nwearables, etc) that run the best apps/services for everyone in the world. \n \nThe US base salary range for this full-time position is $166,000-$244,000 + bonus + equity + \nbenefits. Our salary ranges are determined by role, level, and location. Within the range, \nindividual pay is determined by work location and additional factors, including job-related \nskills, experience, and relevant education or training. Your recruiter can share more about \nthe specific salary range for your preferred location during the hiring process. \n \nPlease note that the compensation details listed in US role postings reflect the base salary \nonly, and do not include bonus, equity, or benefits. Learn more about benefits at Google. \nResponsibilities \n• Write and test product or system development code. \n• Participate in, or lead design reviews with peers and stakeholders to decide \namongst available technologies. \n• Review code developed by other developers and provide feedback to ensure best \npractices (e.g., style guidelines, checking code in, accuracy, testability, and \nefficiency). \n• Contribute to existing documentation or educational content and adapt content \nbased on product/program updates and user feedback. \n• Triage product or system issues and debug/track/resolve by analyzing the sources of \nissues and the impact on hardware, network, or service operations and quality."]

# %%
len(chunk_ques_gen)
# Out:
# 1

# %%
type(chunk_ques_gen[0])
# Out:
# str

# %%
from langchain_core.documents import Document

# %%
document_ques_gen = [Document(page_content=t) for t in chunk_ques_gen]

# %%
document_ques_gen
# Out:
# [Document(metadata={}, page_content="Senior Software Engineer, Engineering Productivity \nGoogleplaceSan Jose, CA, USA \nMinimum qualifications: \n• Bachelor’s degree or equivalent practical experience. \n• 5 years of experience with software development in one or more programming \nlanguages. \n• 3 years of experience working with embedded operating systems. \n• 3 years of experience testing, maintaining, or launching software products. \n• 1 year of experience with software design and architecture. \n \n \n \nPreferred qualifications: \n• Master's degree or PhD in Computer Science or related technical field. \n• 5 years of experience with data structures/algorithms. \n• 1 year of experience in a technical leadership role. \n• Experience developing accessible technologies. \nAbout the job \nGoogle's software engineers develop the next-generation technologies that change how \nbillions of users connect, explore, and interact with information and one another. Our \nproducts need to handle information at massive scale, and extend well beyond web \nsearch. We're looking for engineers who bring fresh ideas from all areas, including \ninformation retrieval, distributed computing, large-scale system design, networking and \ndata storage, security, artificial intelligence, natural language processing, UI design and \nmobile; the list goes on and is growing every day. As a software engineer, you will work on a \nspecific project critical to Google’s needs with opportunities to switch teams and projects \nas you and our fast-paced business grow and evolve. We need our engineers to be versatile, \ndisplay leadership qualities and be enthusiastic to take on new problems across the full-\nstack as we continue to push technology forward. Android is Google’s mobile operating \nsystem powering more than 3 billion devices worldwide. Android is about bringing \ncomputing to everyone in the world. We believe computing is a super power for good,enabling access to information, economic opportunity, productivity, connectivity between \nfriends and family and more. We think everyone in the world should have access to the best \ncomputing has to offer. We provide the platform for original equipment manufacturers \n(OEMs) and developers to build compelling computing devices (smartphones, tablets, TVs, \nwearables, etc) that run the best apps/services for everyone in the world. \n \nThe US base salary range for this full-time position is $166,000-$244,000 + bonus + equity + \nbenefits. Our salary ranges are determined by role, level, and location. Within the range, \nindividual pay is determined by work location and additional factors, including job-related \nskills, experience, and relevant education or training. Your recruiter can share more about \nthe specific salary range for your preferred location during the hiring process. \n \nPlease note that the compensation details listed in US role postings reflect the base salary \nonly, and do not include bonus, equity, or benefits. Learn more about benefits at Google. \nResponsibilities \n• Write and test product or system development code. \n• Participate in, or lead design reviews with peers and stakeholders to decide \namongst available technologies. \n• Review code developed by other developers and provide feedback to ensure best \npractices (e.g., style guidelines, checking code in, accuracy, testability, and \nefficiency). \n• Contribute to existing documentation or educational content and adapt content \nbased on product/program updates and user feedback. \n• Triage product or system issues and debug/track/resolve by analyzing the sources of \nissues and the impact on hardware, network, or service operations and quality.")]

# %%
type(document_ques_gen[0])
# Out:
# langchain_core.documents.base.Document

# %%
splitter_ans_gen = TokenTextSplitter(
    model_name= "gpt-4.1-mini",
    chunk_size= 256,
    chunk_overlap = 25
)

# %%
document_ans_gen = splitter_ans_gen.split_documents(
    document_ques_gen
)

# %%
document_ans_gen
# Out:
# [Document(metadata={}, page_content="Senior Software Engineer, Engineering Productivity \nGoogleplaceSan Jose, CA, USA \nMinimum qualifications: \n• Bachelor’s degree or equivalent practical experience. \n• 5 years of experience with software development in one or more programming \nlanguages. \n• 3 years of experience working with embedded operating systems. \n• 3 years of experience testing, maintaining, or launching software products. \n• 1 year of experience with software design and architecture. \n \n \n \nPreferred qualifications: \n• Master's degree or PhD in Computer Science or related technical field. \n• 5 years of experience with data structures/algorithms. \n• 1 year of experience in a technical leadership role. \n• Experience developing accessible technologies. \nAbout the job \nGoogle's software engineers develop the next-generation technologies that change how \nbillions of users connect, explore, and interact with information and one another. Our \nproducts need to handle information at massive scale, and extend well beyond web \nsearch. We're looking for engineers who bring fresh ideas from all areas, including \ninformation retrieval, distributed computing, large-scale system design, networking and \ndata storage, security, artificial intelligence, natural language processing, UI design and \nmobile; the list goes on and is growing every day. As a software engineer"),
#  Document(metadata={}, page_content=', natural language processing, UI design and \nmobile; the list goes on and is growing every day. As a software engineer, you will work on a \nspecific project critical to Google’s needs with opportunities to switch teams and projects \nas you and our fast-paced business grow and evolve. We need our engineers to be versatile, \ndisplay leadership qualities and be enthusiastic to take on new problems across the full-\nstack as we continue to push technology forward. Android is Google’s mobile operating \nsystem powering more than 3 billion devices worldwide. Android is about bringing \ncomputing to everyone in the world. We believe computing is a super power for good,enabling access to information, economic opportunity, productivity, connectivity between \nfriends and family and more. We think everyone in the world should have access to the best \ncomputing has to offer. We provide the platform for original equipment manufacturers \n(OEMs) and developers to build compelling computing devices (smartphones, tablets, TVs, \nwearables, etc) that run the best apps/services for everyone in the world. \n \nThe US base salary range for this full-time position is $166,000-$244,000 + bonus + equity + \nbenefits. Our salary ranges are determined by role, level, and location'),
#  Document(metadata={}, page_content='-$244,000 + bonus + equity + \nbenefits. Our salary ranges are determined by role, level, and location. Within the range, \nindividual pay is determined by work location and additional factors, including job-related \nskills, experience, and relevant education or training. Your recruiter can share more about \nthe specific salary range for your preferred location during the hiring process. \n \nPlease note that the compensation details listed in US role postings reflect the base salary \nonly, and do not include bonus, equity, or benefits. Learn more about benefits at Google. \nResponsibilities \n• Write and test product or system development code. \n• Participate in, or lead design reviews with peers and stakeholders to decide \namongst available technologies. \n• Review code developed by other developers and provide feedback to ensure best \npractices (e.g., style guidelines, checking code in, accuracy, testability, and \nefficiency). \n• Contribute to existing documentation or educational content and adapt content \nbased on product/program updates and user feedback. \n• Triage product or system issues and debug/track/resolve by analyzing the sources of \nissues and the impact on hardware, network, or service operations and quality.')]

# %%
from langchain_openai import ChatOpenAI

# %%
llm_ques_gen_pipeline = ChatOpenAI(
    model = 'gpt-4.1-mini',
    temperature = 0.3
)

# %%
prompt_template = """
You are an expert at creating questions based on coding job description.
Your goal is to prepare a coder or programmer for their exam and coding tests.
You do this by asking questions based on the job description below:

------------
{text}
------------

Create questions that will prepare the coders or programmers for their tests.
Make sure not to lose any important information.

QUESTIONS:
"""

# %%
from langchain_core.prompts import PromptTemplate

# %%
PROMPT_QUESTIONS = PromptTemplate(template=prompt_template, input_variables=['text'])

# %%
refine_template = ("""
You are an expert at creating practice questions based on coding job description.
Your goal is to help a coder or programmer prepare for a coding test.
We have received some practice questions to a certain extent: {existing_answer}.
We have the option to refine the existing questions or add new ones.
(only if necessary) with some more context below.
------------
{text}
------------

Given the new context, refine the original questions in English.
If the context is not helpful, please provide the original questions.
QUESTIONS:
"""
)

# %%
REFINE_PROMPT_QUESTIONS = PromptTemplate(
    input_variables=["existing_answer", "text"],
    template=refine_template,
)

# %%
from operator import itemgetter
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough

initial_chain = (
    {"text": RunnablePassthrough()} 
    | PROMPT_QUESTIONS 
    | llm_ques_gen_pipeline 
    | StrOutputParser()
)

ques_gen_chain = (
    {
        "existing_answer": initial_chain, 
        "text": RunnablePassthrough() 
    }
    | REFINE_PROMPT_QUESTIONS
    | llm_ques_gen_pipeline
    | StrOutputParser()
)

# %%
# result = ques_gen_chain.invoke(document_ques_gen)

# %%
# Thêm một hàm helper để dọn dẹp khoảng trắng rác
def format_output(text: str):
    # Loại bỏ các đoạn thừa nếu có và đảm bảo xuống dòng sạch sẽ
    return text.strip()

ques_gen_chain_final = ques_gen_chain | format_output

# Khi in ra sẽ dễ nhìn hơn
print(ques_gen_chain_final.invoke(document_ques_gen))
# Out:
# Here is a refined and focused set of practice questions based on the provided job description for the Senior Software Engineer, Engineering Productivity role at Google. The refinements emphasize the key qualifications, responsibilities, and preferred skills highlighted in the document, while maintaining clarity and relevance for coding test and interview preparation:
#
# ---
#
# 1. **Programming Languages & Experience:**
#    What programming languages have you used in your software development career? Please specify the duration of your experience with each and highlight any projects where these languages were critical.
#
# 2. **Embedded Operating Systems:**
#    Describe your experience working with embedded operating systems. What specific challenges did you encounter, and how did you address issues related to resource constraints, real-time requirements, or hardware integration?
#
# 3. **Software Testing, Maintenance, and Launch:**
#    Explain your approach to testing, maintaining, and launching software products. Provide examples where your testing strategy improved product reliability or accelerated deployment.
#
# 4. **Software Design and Architecture:**
#    Discuss your contributions to software design and architecture. Describe a system or product you helped architect, focusing on design decisions that improved scalability, maintainability, or performance.
#
# 5. **Data Structures and Algorithms:**
#    Outline your knowledge and practical experience with data structures and algorithms. How have you applied them to solve complex problems or optimize system performance in your projects?
#
# 6. **Technical Leadership:**
#    Have you held technical leadership roles? Describe your responsibilities, how you facilitated team collaboration, managed project delivery, and influenced technical direction.
#
# 7. **Accessible Technologies:**
#    What experience do you have developing accessible technologies? Why do you believe accessibility is important, and how have you incorporated accessibility considerations into your software?
#
# 8. **Large-Scale System Design and Distributed Computing:**
#    Google’s projects often involve large-scale systems. What are the key considerations when designing scalable, distributed systems? Provide examples from your experience.
#
# 9. **Code Reviews and Best Practices:**
#    How do you approach code reviews? What best practices do you follow to ensure code quality, style consistency, testability, and efficiency?
#
# 10. **Issue Triage and Debugging:**
#     Describe a time when you triaged a complex product or system issue. How did you analyze the problem, identify root causes (including hardware, network, or service-related issues), and resolve it?
#
# 11. **Debugging Hardware, Network, or Service Operations Issues:**
#     Explain your experience debugging problems related to hardware, network, or service operations. What tools and methodologies do you use to pinpoint root causes?
#
# 12. **Documentation and Educational Content:**
#     How do you keep documentation and educational materials up to date in response to product updates and user feedback? Provide examples of your contributions.
#
# 13. **Versatility and Leadership Qualities:**
#     Google values engineers who are versatile and demonstrate leadership. How do you exhibit these traits in your work, especially when adapting to new technologies or projects?
#
# 14. **Motivation for Full-Stack and Rapid Adaptation:**
#     What motivates you to tackle full-stack problems and quickly adapt to new technologies or projects? Share experiences that demonstrate your enthusiasm and adaptability.
#
# 15. **Developing Efficient Software for Diverse Hardware Platforms:**
#     Android runs on billions of devices with varying hardware capabilities. How would you approach developing software that performs efficiently across smartphones, tablets, wearables, and other devices?
#
# 16. **Security Considerations:**
#     Describe your understanding of security in software development, particularly for large-scale or embedded systems. How have you incorporated security best practices into your work?
#
# 17. **Staying Current with Emerging Technologies:**
#     How do you keep up with emerging technologies such as artificial intelligence, natural language processing, or UI design? Provide examples of how you have integrated new technologies into your projects.
#
# 18. **Compensation Negotiation:**
#     Given the salary range and benefits described, how do you evaluate your skills and experience to negotiate compensation effectively during the hiring process?
#
# ---
#
# If you want, I can also help create coding or system design exercises based on these topics. Let me know!

# %%
result
# Out:
# 'Based on the provided job description and context for the Senior Software Engineer, Engineering Productivity role at Google, here is a refined and focused set of practice questions. These questions emphasize the key qualifications, responsibilities, and preferred skills mentioned, ensuring relevance and depth for preparation:\n\n---\n\n1. **Embedded Operating Systems Experience**  \nDescribe your experience working with embedded operating systems. What specific challenges have you encountered when developing, testing, or maintaining software on embedded platforms, and how did you overcome them?\n\n2. **Software Design and Architecture**  \nExplain the importance of software design and architecture in large-scale system development. Can you provide an example of a design pattern or architectural style you have applied in a project, particularly one that improved system scalability or maintainability?\n\n3. **Writing and Testing Code for Reliability**  \nHow do you approach writing and testing product or system development code to ensure reliability, maintainability, and efficiency? Please include any tools, methodologies, or frameworks you use.\n\n4. **Data Structures and Algorithms Application**  \nDiscuss your experience with data structures and algorithms. How have you applied them to optimize software performance in real-world projects, especially in large-scale or embedded systems?\n\n5. **Design Reviews and Technology Decisions**  \nWhat strategies do you use when participating in or leading design reviews? How do you evaluate and decide among competing technologies or approaches in a collaborative environment?\n\n6. **Code Review Best Practices**  \nHow do you conduct code reviews for other developers? What key aspects do you focus on to ensure adherence to style guidelines, accuracy, testability, efficiency, and overall code quality?\n\n7. **Issue Triage and Debugging**  \nDescribe your process for triaging product or system issues. How do you analyze and resolve problems that impact hardware, network, or service operations? Include any debugging tools or techniques you find effective.\n\n8. **Documentation and Educational Content Contribution**  \nHave you contributed to documentation or educational materials for software products? How do you ensure this content remains current and useful based on product updates and user feedback?\n\n9. **Technical Leadership Experience**  \nWhat experience do you have in a technical leadership role? How do you motivate, guide, and support a development team to achieve project goals and maintain high engineering standards?\n\n10. **Developing Accessible Technologies**  \nHow would you approach developing accessible technologies? Why is accessibility important in software development, and what best practices do you follow to ensure inclusivity?\n\n11. **Distributed Computing and Large-Scale System Design**  \nExplain how principles of distributed computing and large-scale system design can be applied to handle massive-scale information processing. Provide examples from your experience if possible.\n\n12. **Mobile Operating Systems and Android Development**  \nDescribe your familiarity with Android or other mobile operating systems. How does developing for mobile platforms differ from other environments, and what unique challenges have you faced?\n\n13. **Versatility and Enthusiasm in a Fast-Paced Environment**  \nHow do you stay versatile and enthusiastic about tackling new problems across the full stack in a fast-paced engineering environment? Share examples of how you have adapted to changing priorities or technologies.\n\n14. **Programming Languages Proficiency**  \nWhat programming languages are you proficient in? Provide examples of how you have used these languages in software development projects, particularly in embedded or large-scale systems.\n\n15. **Debugging Complex Hardware/Network/Service Issues**  \nDiscuss a time when you debugged a complex issue involving hardware, n ...
